# %%
# !pip install tensorflow opencv-python matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (2.11.0)
# Requirement already satisfied: opencv-python in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (4.6.0.66)
# Requirement already satisfied: matplotlib in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (3.6.2)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.23.5)
# Requirement already satisfied: setuptools in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (65.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.3.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (14.0.6)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.7.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.28.0)
# Requirement already satisfied: packaging in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.3)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (22.11.23)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.50.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.2.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.14.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\razer\anaconda3\envs\dl_venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)

# %%
import tensorflow as tf
import os
import cv2
import imghdr
image_directory = 'images'
image_extensions = ['jpeg', 'jpg', 'bmp', 'png']

# %%
# Show the number of kitten images 
len(os.listdir(os.path.join(image_directory, 'kittens')))
# Out:
# 149

# %%
# Show the number of pupper images 
len(os.listdir(os.path.join(image_directory, 'puppers')))
# Out:
# 158

# %%
for image_class in os.listdir(image_directory):
    for image in os.listdir(os.path.join(image_directory, image_class)):
        image_path = os.path.join(image_directory, image_class, image)
        try:
            # Checa que podamos cargar la imágen en opencv
            img = cv2.imread(image_path)
            # Checa que nuestra imagen tenga las extension permitida
            img_ext = imghdr.what(image_path)
            if img_ext not in image_extensions:
                print(f'La extención {img_ext} no esta permitida')
                os.remove(image_path)
        except Exception as e:
            print(f'La imagen {image_path} tiene un problema')
            os.remove(image_path)

# %%
# Show the number of kitten images 
len(os.listdir(os.path.join(image_directory, 'kittens')))
# Out:
# 149

# %%
# Show the number of pupper images 
len(os.listdir(os.path.join(image_directory, 'puppers')))
# Out:
# 158

# %%
import numpy as np
from matplotlib import pyplot as plt
# cargar imagenes, el método se encarga de dividir nuestras imagenes de forma aleatoria en bloques de 32
images = tf.keras.utils.image_dataset_from_directory('images')
# Out:
# Found 307 files belonging to 2 classes.

# %%
image_iterator = images.as_numpy_iterator()

# %%
# nos permite cambiar el conjunto de imagenes que estamos usando
# label 0 = kittens
# label 1 = puppers
batch = image_iterator.next()

# %%
fig, ax = plt.subplots(ncols = 4, figsize = (20, 20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
# Vamos a cambiar la representación de los valores numéricos de las imagenes de (0 - 255) a (0 - 1)
images = images.map(lambda x, y: (x/255, y))
# Out:
# WARNING:tensorflow:From c:\Users\Razer\anaconda3\envs\DL_venv\lib\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
len(images)
# Out:
# 10

# %%
train_size = int(len(images)*.7)
validation_size = int(len(images)*.2)+1
test_size = int(len(images)*.1)+1

# %%
train_size + validation_size + test_size
# Out:
# 12

# %%
# train_data -> Imágenes que se usaran para entrenar el modelo
train_data = images.take(train_size)
# validation_data -> Imágenes que se usaran para evaluar el modelo mientras se entrena
validation_data = images.skip(train_size).take(validation_size)
# test_data -> Imágenes que el modelo nunca ha visto
test_data = images.skip(train_size + validation_size).take(test_size)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3, 3), 1, activation='relu', input_shape=(256, 256, 3)))
model.add(MaxPooling2D())

model.add(Conv2D(32, (3, 3), 1, activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(16, (3, 3), 1, activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________

# %%
log_directory = 'logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_directory)

# %%
hist = model.fit(train_data, epochs = 20, validation_data = validation_data, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 7/7 [==============================] - 8s 932ms/step - loss: 0.8663 - accuracy: 0.5491 - val_loss: 0.6863 - val_accuracy: 0.5542
# Epoch 2/20
# 7/7 [==============================] - 6s 734ms/step - loss: 0.6815 - accuracy: 0.6473 - val_loss: 0.6416 - val_accuracy: 0.6988
# Epoch 3/20
# 7/7 [==============================] - 6s 765ms/step - loss: 0.6808 - accuracy: 0.5536 - val_loss: 0.6017 - val_accuracy: 0.7590
# Epoch 4/20
# 7/7 [==============================] - 6s 721ms/step - loss: 0.5996 - accuracy: 0.7009 - val_loss: 0.6754 - val_accuracy: 0.4819
# Epoch 5/20
# 7/7 [==============================] - 6s 704ms/step - loss: 0.5502 - accuracy: 0.6920 - val_loss: 0.5446 - val_accuracy: 0.7229
# Epoch 6/20
# 7/7 [==============================] - 6s 777ms/step - loss: 0.5049 - accuracy: 0.7411 - val_loss: 0.4736 - val_accuracy: 0.8675
# Epoch 7/20
# 7/7 [==============================] - 6s 777ms/step - loss: 0.4126 - accuracy: 0.8705 - val_loss: 0.2855 - val_accuracy: 0.9277
# Epoch 8/20
# 7/7 [==============================] - 6s 723ms/step - loss: 0.3025 - accuracy: 0.8661 - val_loss: 0.2501 - val_accuracy: 0.9157
# Epoch 9/20
# 7/7 [==============================] - 6s 728ms/step - loss: 0.2179 - accuracy: 0.9062 - val_loss: 0.1736 - val_accuracy: 0.9518
# Epoch 10/20
# 7/7 [==============================] - 6s 729ms/step - loss: 0.1569 - accuracy: 0.9554 - val_loss: 0.0747 - val_accuracy: 1.0000
# Epoch 11/20
# 7/7 [==============================] - 6s 749ms/step - loss: 0.1077 - accuracy: 0.9732 - val_loss: 0.1243 - val_accuracy: 0.9518
# Epoch 12/20
# 7/7 [==============================] - 6s 790ms/step - loss: 0.0836 - accuracy: 0.9777 - val_loss: 0.0345 - val_accuracy: 1.0000
# Epoch 13/20
# 7/7 [==============================] - 6s 721ms/step - loss: 0.0746 - accuracy: 0.9821 - val_loss: 0.0465 - val_accuracy: 1.0000
# Epoch 14/20
# 7/7 [==============================] - 6s 735ms/step - loss: 0.0512 - accuracy: 0.9911 - val_loss: 0.0523 - val_accuracy: 1.0000
# Epoch 15/20
# 7/7 [==============================] - 6s 731ms/step - loss: 0.0563 - accuracy: 0.9821 - val_loss: 0.0285 - val_accuracy: 0.9880
# Epoch 16/20
# 7/7 [==============================] - 6s 728ms/step - loss: 0.0186 - accuracy: 0.9955 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 17/20
# 7/7 [==============================] - 6s 729ms/step - loss: 0.0345 - accuracy: 0.9955 - val_loss: 0.0275 - val_accuracy: 0.9880
# Epoch 18/20
# 7/7 [==============================] - 6s 724ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.0445 - val_accuracy: 0.9759
# Epoch 19/20
# 7/7 [==============================] - 6s 730ms/step - loss: 0.0237 - accuracy: 0.9911 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 20/20
# 7/7 [==============================] - 6s 739ms/step - loss: 0.0088 - accuracy: 0.9955 - val_loss: 0.0012 - val_accuracy: 1.0000

# %%
figure = plt.figure()
plt.plot(hist.history['loss'], color='orange', label='loss')
plt.plot(hist.history['val_loss'], color='purple', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc='upper left')
plt.show()

# %%
figure = plt.figure()
plt.plot(hist.history['accuracy'], color='orange', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='purple', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc='upper left')
plt.show()

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
precision = Precision()
recall = Recall()
accuracy = BinaryAccuracy()

# %%
for batch in test_data.as_numpy_iterator():
    X, y = batch
    yhat = model.predict(X)
    precision.update_state(y, yhat)
    recall.update_state(y, yhat)
    accuracy.update_state(y, yhat)

# %%
print(f'Precision: {precision.result().numpy()}\nRecall: {recall.result().numpy()}\nAccuracy: {accuracy.result().numpy()}')
# Out:
# Precision: 0.0
# Recall: 0.0
# Accuracy: 0.0
